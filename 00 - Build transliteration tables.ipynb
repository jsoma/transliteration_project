# %% [markdown]
# ## Build transliteration table
#
# Pull table from riptsource.org/cms/scripts/page.php?item_id=entry_detail&uid=vsytndbyev and build both forward and reserve transliteration tables.

# %%
import requests
import pandas as pd
import unidecode
import numpy as np

# %%
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'
headers = {'User-Agent': user_agent}
response = requests.get('https://scriptsource.org/cms/scripts/page.php?item_id=entry_detail&uid=vsytndbyev', headers=headers)

# %%
results = pd.read_html(response.text)
df = results[1]
df.head()
# Out:
#    Glyph   USV ALA-LC Alone-Stokes B&D Campbell Chaîne Cohen Dawkins  \
# 0    NaN  1200     ha           hā  hä       ha     hă    ha      hä
# 1    NaN  1201     hu           hu  hu       hū     hu    hu      hu
# 2    NaN  1202     hi           hī  hi       hī     hi    hi      hi
# 3    NaN  1203     hā           hā  ha       hā     ha    ha      ha
# 4    NaN  1204     hé           hē  he       hē     he    he      he
#
#   Dept of State ethiop SERA
# 0            ha     ha   he
# 1            hu     hu   hu
# 2            hi     hi   hi
# 3            ha     hā   ha
# 4            he     hē   hE

# %% [markdown]
# We can't see the glyph because it was an image! So we'll convert the Unicode code - `USV` - to the character.

# %%
df.Glyph = df.USV.apply(lambda val: chr(int(val, 16)))
df.head()
# Out:
#   Glyph   USV ALA-LC Alone-Stokes B&D Campbell Chaîne Cohen Dawkins  \
# 0     ሀ  1200     ha           hā  hä       ha     hă    ha      hä
# 1     ሁ  1201     hu           hu  hu       hū     hu    hu      hu
# 2     ሂ  1202     hi           hī  hi       hī     hi    hi      hi
# 3     ሃ  1203     hā           hā  ha       hā     ha    ha      ha
# 4     ሄ  1204     hé           hē  he       hē     he    he      he
#
#   Dept of State ethiop SERA
# 0            ha     ha   he
# 1            hu     hu   hu
# 2            hi     hi   hi
# 3            ha     hā   ha
# 4            he     hē   hE

# %% [markdown]
# We'll save this one for now as a CSV (although we probably won't use it)

# %%
df.to_csv("transliteration-table.csv", index=False)

# %% [markdown]
# ## Simplified transliteration table

# %%
df = pd.read_csv("transliteration-table.csv")
df = df.drop(columns=['USV'])
df = df.set_index('Glyph')
df
# Out:
#       ALA-LC Alone-Stokes  B&D Campbell Chaîne Cohen Dawkins Dept of State  \
# Glyph
# ሀ         ha           hā   hä       ha     hă    ha      hä            ha
# ሁ         hu           hu   hu       hū     hu    hu      hu            hu
# ሂ         hi           hī   hi       hī     hi    hi      hi            hi
# ሃ         hā           hā   ha       hā     ha    ha      ha            ha
# ሄ         hé           hē   he       hē     he    he      he            he
# ...      ...          ...  ...      ...    ...   ...     ...           ...
# ᎎ        NaN          NaN  NaN      NaN    NaN   NaN     NaN           NaN
# ᎏ        NaN          NaN  NaN      NaN    NaN   NaN     NaN           NaN
# ፘ        rya          NaN  NaN      NaN    NaN   rya     rya           NaN
# ፙ        mya          NaN  NaN      NaN    NaN   mya     NaN           NaN
# ፚ        fya          NaN  NaN      NaN    NaN   fya     NaN           NaN
#
#       ethiop SERA
# Glyph
# ሀ         ha   he
# ሁ         hu   hu
# ሂ         hi   hi
# ሃ         hā   ha
# ሄ         hē   hE
# ...      ...  ...
# ᎎ        pwē  pWE
# ᎏ        pwe   pW
# ፘ        ~ri  NaN
# ፙ        ~mA  NaN
# ፚ        ~fi  NaN
#
# [368 rows x 10 columns]

# %% [markdown]
# We're really just looking at ASCII Latin transliteraitons, so we'll turn `hā` into `ha`, etc.

# %%
def simplify(value):
    try:
        return unidecode.unidecode(value).lower()
    except:
        return np.nan
    
simplified = df.applymap(simplify)
simplified
# Out:
#       ALA-LC Alone-Stokes  B&D Campbell Chaîne Cohen Dawkins Dept of State  \
# Glyph
# ሀ         ha           ha   ha       ha     ha    ha      ha            ha
# ሁ         hu           hu   hu       hu     hu    hu      hu            hu
# ሂ         hi           hi   hi       hi     hi    hi      hi            hi
# ሃ         ha           ha   ha       ha     ha    ha      ha            ha
# ሄ         he           he   he       he     he    he      he            he
# ...      ...          ...  ...      ...    ...   ...     ...           ...
# ᎎ        NaN          NaN  NaN      NaN    NaN   NaN     NaN           NaN
# ᎏ        NaN          NaN  NaN      NaN    NaN   NaN     NaN           NaN
# ፘ        rya          NaN  NaN      NaN    NaN   rya     rya           NaN
# ፙ        mya          NaN  NaN      NaN    NaN   mya     NaN           NaN
# ፚ        fya          NaN  NaN      NaN    NaN   fya     NaN           NaN
#
#       ethiop SERA
# Glyph
# ሀ         ha   he
# ሁ         hu   hu
# ሂ         hi   hi
# ሃ         ha   ha
# ሄ         he   he
# ...      ...  ...
# ᎎ        pwe  pwe
# ᎏ        pwe   pw
# ፘ        ~ri  NaN
# ፙ        ~ma  NaN
# ፚ        ~fi  NaN
#
# [368 rows x 10 columns]

# %%
# Break apart h/ha into h and ha
uniqued = simplified.fillna('').apply(lambda row: list(set([v for v in row.values if v and '/' not in str(v)])), axis=1)

# Remove anything that involves @ or ~
uniqued = uniqued.apply(lambda row: [v for v in row if '@' not in v])

# Remove ~ (but keep the rest)
uniqued = uniqued.apply(lambda row: [v.replace('~', '') for v in row])

uniqued
# Out:
# Glyph
# ሀ     [he, ha]
# ሁ         [hu]
# ሂ         [hi]
# ሃ         [ha]
# ሄ         [he]
#        ...
# ᎎ        [pwe]
# ᎏ    [pwe, pw]
# ፘ    [ri, rya]
# ፙ    [ma, mya]
# ፚ    [fi, fya]
# Length: 368, dtype: object

# %% [markdown]
# ### Add punctuation

# %%
punctuation = {
    '።': ['.'],
    '፡': [' '],
    '፣': [','],
    '፤': [';'],
    '፥': [':'],
    '፧': ['?'],
    '፦': [':']
}

uniqued = pd.concat([pd.Series(punctuation), uniqued])
uniqued
# Out:
# ።          [.]
# ፡          [ ]
# ፣          [,]
# ፤          [;]
# ፥          [:]
#        ...
# ᎎ        [pwe]
# ᎏ    [pwe, pw]
# ፘ    [ri, rya]
# ፙ    [ma, mya]
# ፚ    [fi, fya]
# Length: 375, dtype: object

# %% [markdown]
# ### Save

# %%
uniqued.to_json("eth_lat.json")

# %%
import json

with open("eth_lat.json") as f:
    eth_lat = json.load(f)

eth_lat
# Out:
# {'።': ['.'],
#  '፡': [' '],
#  '፣': [','],
#  '፤': [';'],
#  '፥': [':'],
#  '፧': ['?'],
#  '፦': [':'],
#  'ሀ': ['he', 'ha'],
#  'ሁ': ['hu'],
#  'ሂ': ['hi'],
#  'ሃ': ['ha'],
#  'ሄ': ['he'],
#  'ህ': ['he', 'h', 'hi'],
#  'ሆ': ['hwo', 'ho'],
#  'ለ': ['la', 'le'],
#  'ሉ': ['lu'],
#  'ሊ': ['li'],
#  'ላ': ['la'],
#  'ሌ': ['lye', 'le'],
#  'ል': ['l', 'li', 'le'],
#  'ሎ': ['lwo', 'lo'],
#  'ሏ': ['lwa'],
#  'ሐ': ['he', 'ha'],
#  'ሑ': ['hu'],
#  'ሒ': ['hi'],
#  'ሓ': ['ha'],
#  'ሔ': ['he'],
#  'ሕ': ['he', 'h', 'hi'],
#  'ሖ': ['hwo', 'ho'],
#  'ሗ': ['hwa'],
#  'መ': ['ma', 'me'],
#  'ሙ': ['mu'],
#  'ሚ': ['mi'],
#  'ማ': ['ma'],
#  'ሜ': ['me', 'mye'],
#  'ም': ['m', 'me', 'mi'],
#  'ሞ': ['mo', 'mwo'],
#  'ᎀ': ['mwe', 'mwa'],
#  'ᎁ': ['mwi'],
#  'ሟ': ['mwa'],
#  'ᎂ': ['mwe'],
#  'ᎃ': ['mwe', 'mw'],
#  'ሠ': ['sa', "'se"],
#  'ሡ': ['su', "'su"],
#  'ሢ': ['si', "'si"],
#  'ሣ': ['sa', "'sa"],
#  'ሤ': ['se', 'sye', "'se"],
#  'ሥ': ['se', "'s", 'si'],
#  'ሦ': ["'so", 'swo', 'so'],
#  'ሧ': ["'swa", 'swa'],
#  'ረ': ['re', 'ra'],
#  'ሩ': ['ru'],
#  'ሪ': ['ri'],
#  'ራ': ['ra'],
#  'ሬ': ['re', 'rye'],
#  'ር': ['re', 'r', 'ri'],
#  'ሮ': ['ro', 'rwo'],
#  'ሯ': ['rwa'],
#  'ሰ': ['sa', 'se'],
#  'ሱ': ['su'],
#  'ሲ': ['si'],
#  'ሳ': ['sa'],
#  'ሴ': ['se', 'sye'],
#  'ስ': ['se', 's', 'si'],
#  'ሶ': ['swo', 'so'],
#  'ሷ': ['swa'],
#  'ሸ': ['xe', 'sha', 'sa', 'cha'],
#  'ሹ': ['su', 'xu', 'chu', 'shu'],
#  'ሺ': ['shi', 'xi', 'si', 'chi'],
#  'ሻ': ['sa', 'sha', 'xa', 'cha'],
#  'ሼ': ['she', 'se', 'xe', 'che'],
#  'ሽ': ['se', 'che', 'shi', 'x', 'si'],
#  'ሾ': ['swo', 'cho', 'so', 'xo', 'sho'],
#  'ሿ': ['xwa', 'shwa', 'swa'],
#  'ቀ': ['qa', 'qe', 'ka'],
#  'ቁ': ['qu', 'ku'],
#  'ቂ': ['qi', 'ki'],
#  'ቃ': ['qa', 'ka'],
#  'ቄ': ['qe', 'qye', 'ke'],
#  'ቅ': ['q', 'qe', 'ki'],
#  'ቆ': ['ko', 'qwo', 'qo'],
#  'ቇ': [],
#  'ቈ': ['qwa', 'kwa', 'qwe', 'qua', 'kwe'],
#  'ቊ': ['qui', 'kwi', 'qwi'],
#  'ቋ': ['kwa', 'qua', 'qwa'],
#  'ቌ': ['que', 'kwe', 'qwe'],
#  'ቍ': ['que', 'qw', 'qwe', 'kwi'],
#  'ⷀ': ['qa', "'qe"],
#  'ⷁ': ['qu', "'qu"],
#  'ⷂ': ['qi', "'qi"],
#  'ⷃ': ['qa', "'qa"],
#  'ⷄ': ["'qe", 'qe'],
#  'ⷅ': ['qe', "'q"],
#  'ⷆ': ['qo', "'qo"],
#  'ቐ': ['qa', 'qe'],
#  'ቑ': ['qu', 'qi'],
#  'ቒ': ['qa', 'qi'],
#  'ቓ': ['qa'],
#  'ቔ': ['qe'],
#  'ቕ': ['q', 'qo', 'qe'],
#  'ቖ': ['qo'],
#  'ቘ': ['qwa', 'qwe'],
#  'ቚ': ['qwi'],
#  'ቛ': ['qwa'],
#  'ቜ': ['qwe'],
#  'ቝ': ['qw', 'qwe'],
#  'በ': ['ba', 'be'],
#  'ቡ': ['bu'],
#  'ቢ': ['bi'],
#  'ባ': ['ba'],
#  'ቤ': ['be', 'bye'],
#  'ብ': ['be', 'bi', 'b'],
#  'ቦ': ['bwo', 'bo'],
#  'ᎄ': ['bwe', 'bwa'],
#  'ᎅ': ['bwi'],
#  'ቧ': ['bwa'],
#  'ᎆ': ['bwe'],
#  'ᎇ': ['bw', 'bwe'],
#  'ቨ': ['ve', 'va'],
#  'ቩ': ['vu'],
#  'ቪ': ['vi'],
#  'ቫ': ['va'],
#  'ቬ': ['ve'],
#  'ቭ': ['ve', 'v', 'vi'],
#  'ቮ': ['vo'],
#  'ቯ': ['vwa'],
#  'ተ': ['ta', 'te'],
#  'ቱ': ['tu'],
#  'ቲ': ['ti'],
#  'ታ': ['ta'],
#  'ቴ': ['tye', 'te'],
#  'ት': ['t', 'ti', 'te'],
#  'ቶ': ['two', 'to'],
#  'ቷ': ['twa'],
#  'ቸ': ['ce', 'ca', 'tcha', 'cha'],
#  'ቹ': ['tchu', 'cu', 'chu'],
#  'ቺ': ['ci', 'tchi', 'chi'],
#  'ቻ': ['cha', 'ca', 'tcha'],
#  'ቼ': ['che', 'tche', 'ce'],
#  'ች': ['ci', 'tche', 'ce', 'c', 'chi'],
#  'ቾ': ['cwo', 'co', 'tcho', 'cho'],
#  'ቿ': ['chwa', 'cwa'],
#  'ኀ': ['ha', "'he"],
#  'ኁ': ["'hu", 'hu'],
#  'ኂ': ["'hi", 'hi'],
#  'ኃ': ['ha', "'ha"],
#  'ኄ': ['he', "'he"],
#  'ኅ': ['he', "'h", 'hi'],
#  'ኆ': ['hwo', "'ho", 'ho'],
#  'ኈ': ['hwe', 'hwa', 'hua'],
#  'ኊ': ['hwi', 'hui'],
#  'ኋ': ['hwa', 'hua'],
#  'ኌ': ['hwe', 'hue'],
#  'ኍ': ['hwe', 'hue', 'hwi', 'hw'],
#  'ነ': ['na', 'ne'],
#  'ኑ': ['nu'],
#  'ኒ': ['ni'],
#  'ና': ['na', "na'"],
#  'ኔ': ['nye', 'ne'],
#  'ን': ['ni', 'ne', 'n'],
#  'ኖ': ['nwo', 'no'],
#  'ኗ': ['nwa'],
#  'ኘ': ['gna', 'na', 'ne'],
#  'ኙ': ['gnu', 'nu'],
#  'ኚ': ['gni', 'ni'],
#  'ኛ': ['gna', 'na'],
#  'ኜ': ['gne', 'ne'],
#  'ኝ': ['gne', 'ne', 'n', 'ni'],
#  'ኞ': ['gno', 'nwo', 'no'],
#  'ኟ': ['nwa'],
#  'አ': ['`a', "'a", 'a'],
#  'ኡ': ['`u', "'u", 'u'],
#  'ኢ': ["'i", 'i', '`i'],
#  'ኣ': ['`a', "'a", 'a'],
#  'ኤ': ['e', 'ye', "'e", '`e'],
#  'እ': ["'e", 'i', '`e'],
#  'ኦ': ["'o", 'o', 'wo', '`o'],
#  'ኧ': ["'wa", 'a-', 'ea', 'a'],
#  'ከ': ['ke', 'ka'],
#  'ኩ': ['ku'],
#  'ኪ': ['ki'],
#  'ካ': ['ka'],
#  'ኬ': ['kye', 'ke'],
#  'ክ': ['ki', 'ke', 'k'],
#  'ኮ': ['ko', 'kwo'],
#  'ኯ': [],
#  'ኰ': ['kwa', 'kua', 'kwe'],
#  'ኲ': ['kui', 'kwi'],
#  'ኳ': ['kwa', 'kua'],
#  'ኴ': ['kue', 'kwe'],
#  'ኵ': ['kue', 'kw', 'kwi', 'kwe'],
#  'ⷈ': ["'ke", 'ka'],
#  'ⷉ': ["'ku", 'ku'],
#  'ⷊ': ['ki', "'ki"],
#  'ⷋ': ["'ka", 'ka'],
#  'ⷌ': ["'ke", 'ke'],
#  'ⷍ': ['ke', "'k"],
#  'ⷎ': ['ko', "'ko"],
#  'ኸ': ['xa', 'ka', 'kha', 'ha', 'ke'],
#  'ኹ': ['khu', 'xu', 'ku', 'hu'],
#  'ኺ': ['hi', 'ki', 'xi', 'khi'],
#  'ኻ': ['ha', 'ka', 'xa', 'kha'],
#  'ኼ': ['xe', 'khe', 'hye', 'he', 'ke'],
#  'ኽ': ['khe', 'hi', 'ke', 'k'],
#  'ኾ': ['ko', 'kho', 'hwo', 'ho', 'xo'],
#  'ዀ': ['kwa', 'kwe'],
#  'ዂ': ['kwi'],
#  'ዃ': ['kwa', 'hwa'],
#  'ዄ': ['kwe'],
#  'ዅ': ['kwe', 'kw'],
#  'ⷐ': ['xe', 'ha'],
#  'ⷑ': ['xu', 'hu'],
#  'ⷒ': ['xi', 'hi'],
#  'ⷓ': ['ha', 'xa'],
#  'ⷔ': ['he', 'xe'],
#  'ⷕ': ['he', 'x'],
#  'ⷖ': ['xo', 'ho'],
#  'ወ': ['wa', 'we'],
#  'ዉ': ['wu'],
#  'ዊ': ['wi'],
#  'ዋ': ['wa'],
#  'ዌ': ['we', 'wye'],
#  'ው': ['we', 'w', 'wi'],
#  'ዎ': ['wo'],
#  'ዐ': ["'e", "'a", '`a', 'a'],
#  'ዑ': ['`u', "'u", 'u'],
#  'ዒ': ["'i", 'i', '`i'],
#  'ዓ': ["'a", '`a', 'a'],
#  'ዔ': ['e', 'ye', "'e", '`e'],
#  'ዕ': ['i', "'e", '`e', "'i"],
#  'ዖ': ["'o", 'o', 'wo', '`o'],
#  'ዘ': ['za', 'ze'],
#  'ዙ': ['zu'],
#  'ዚ': ['zi'],
#  'ዛ': ['za'],
#  'ዜ': ['zye', 'ze'],
#  'ዝ': ['zi', 'z', 'ze'],
#  'ዞ': ['zo', 'zwo'],
#  'ዟ': ['zwa'],
#  'ዠ': ['za', 'ja', 'ze', 'zha'],
#  'ዡ': ['ju', 'zu', 'zhu'],
#  'ዢ': ['ji', 'zi', 'zhi'],
#  'ዣ': ['za', 'ja', 'zha'],
#  'ዤ': ['ze', 'je', 'zhe'],
#  'ዥ': ['zhi', 'zi', 'je', 'z', 'ze'],
#  'ዦ': ['zo', 'jo', 'zwo', 'zho'],
#  'ዧ': ['zhwa', 'zwa'],
#  'የ': ['ye', 'ya', 'ja'],
#  'ዩ': ['ju', 'yu'],
#  'ዪ': ['ji', 'yi'],
#  'ያ': ['ya', 'ja'],
#  'ዬ': ['ye', 'je'],
#  'ይ': ['ye', 'yi', 'y', 'je'],
#  'ዮ': ['jo', 'yo'],
#  'ደ': ['da', 'de'],
#  'ዱ': ['du'],
#  'ዲ': ['di'],
#  'ዳ': ['da'],
#  'ዴ': ['de', 'dye'],
#  'ድ': ['d', 'di', 'de'],
#  'ዶ': ['dwo', 'do'],
#  'ዷ': ['dwa'],
#  'ዸ': ['da', 'de'],
#  'ዹ': ['du'],
#  'ዺ': ['di'],
#  'ዻ': ['da'],
#  'ዼ': ['de'],
#  'ዽ': ['d', 'de'],
#  'ዾ': ['do'],
#  'ዿ': ['dwa'],
#  'ጀ': ['dja', 'ja', 'je', 'ga'],
#  'ጁ': ['ju', 'gu', 'dju'],
#  'ጂ': ['ji', 'dji', 'gi'],
#  'ጃ': ['dja', 'ja', 'ga'],
#  'ጄ': ['dje', 'ge', 'je'],
#  'ጅ': ['ji', 'j', 'ge', 'dje'],
#  'ጆ': ['gwo', 'go', 'jo', 'djo'],
#  'ጇ': ['gwa', 'jwa'],
#  'ገ': ['ge', 'ga'],
#  'ጉ': ['gu'],
#  'ጊ': ['gi'],
#  'ጋ': ['ga'],
#  'ጌ': ['gye', 'ge'],
#  'ግ': ['gi', 'g', 'ge'],
#  'ጎ': ['go', 'gwo'],
#  'ጐ': ['gua', 'gwe', 'gwa'],
#  'ጒ': ['gui', 'gwi'],
#  'ጓ': ['gua', 'gwa'],
#  'ጔ': ['gue', 'gwe'],
#  'ጕ': ['gue', 'gwe', 'gw', 'gwi'],
#  'ⷘ': ["'ge", 'ga'],
#  'ⷙ': ['gu', "'gu"],
#  'ⷚ': ['gi', "'gi"],
#  'ⷛ': ["'ga", 'ga'],
#  'ⷜ': ["'ge", 'ge'],
#  'ⷝ': ["'g", 'ge'],
#  'ⷞ': ['go', "'go"],
#  'ጘ': ['ge', 'ga'],
#  'ጙ': ['gu'],
#  'ጚ': ['gi'],
#  'ጛ': ['ga'],
#  'ጜ': ['ge'],
#  'ጝ': ['g', 'ge'],
#  'ጞ': ['go'],
#  'ⶓ': ['gwe', 'gwa'],
#  'ⶔ': ['gwi'],
#  'ጟ': ['gwa'],
#  'ⶕ': ['gwe'],
#  'ⶖ': ['gw', 'gwe'],
#  'ጠ': ['ta', 'te'],
#  'ጡ': ['tu'],
#  'ጢ': ['ti'],
#  'ጣ': ['ta'],
#  'ጤ': ['tye', 'te'],
#  'ጥ': ['t', 'ti', 'te'],
#  'ጦ': ['two', 'to'],
#  'ጧ': ['twa'],
#  'ጨ': ['ce', "tch'a", 'ca', 'cha'],
#  'ጩ': ['cu', 'chu', "tch'u"],
#  'ጪ': ['ci', "tch'i", 'chi'],
#  'ጫ': ['cha', "tch'a", 'ca'],
#  'ጬ': ['che', 'ce', "tch'e"],
#  'ጭ': ['ci', 'ce', "tch'e", 'c', 'chi'],
#  'ጮ': ['cwo', 'co', "tch'o", 'cho'],
#  'ጯ': ['chwa', 'cwa'],
#  'ጰ': ['pe', 'pa'],
#  'ጱ': ['pu'],
#  'ጲ': ['pi'],
#  'ጳ': ['pa'],
#  'ጴ': ['pye', 'pe'],
#  'ጵ': ['pe', 'p', 'pi'],
#  'ጶ': ['po', 'pwo'],
#  'ጷ': ['pwa'],
#  'ጸ': ['sa', 'tsa', 'se'],
#  'ጹ': ['su', 'tsu'],
#  'ጺ': ['tsi', 'si'],
#  'ጻ': ['sa', 'tsa'],
#  'ጼ': ['se', 'tse', 'sye'],
#  'ጽ': ['se', 's', 'si'],
#  'ጾ': ['tso', 'swo', 'so'],
#  'ጿ': ['swa'],
#  'ፀ': ['da', "'se", 'ca', 'tsa', 'sa'],
#  'ፁ': ['su', 'cu', "'su", 'du', 'tsu'],
#  'ፂ': ['ci', 'tsi', "'si", 'si', 'di'],
#  'ፃ': ['da', 'ca', 'tsa', "'sa", 'sa'],
#  'ፄ': ['se', 'ce', "'se", 'sye', 'tse', 'de'],
#  'ፅ': ["'s", 'ce', 'si', 'de'],
#  'ፆ': ['swo', 'do', 'so', 'co', 'tso', "'so"],
#  'ፈ': ['fe', 'fa'],
#  'ፉ': ['fu'],
#  'ፊ': ['fi'],
#  'ፋ': ['fa'],
#  'ፌ': ['fe', 'fye'],
#  'ፍ': ['fe', 'f', 'fi'],
#  'ፎ': ['fo', 'fwo'],
#  'ᎈ': ['fwa', 'fwe'],
#  'ᎉ': ['fwi'],
#  'ፏ': ['fwa'],
#  'ᎊ': ['fwe'],
#  'ᎋ': ['fw', 'fwe'],
#  'ፐ': ['pe', 'pa'],
#  'ፑ': ['pu'],
#  'ፒ': ['pi'],
#  'ፓ': ['pa'],
#  'ፔ': ['pye', 'pe'],
#  'ፕ': ['pe', 'p', 'pi'],
#  'ፖ': ['po', 'pwo'],
#  'ᎌ': ['pwe', 'pwa'],
#  'ᎍ': ['pwi'],
#  'ፗ': ['pwa'],
#  'ᎎ': ['pwe'],
#  'ᎏ': ['pwe', 'pw'],
#  'ፘ': ['ri', 'rya'],
#  'ፙ': ['ma', 'mya'],
#  'ፚ': ['fi', 'fya']}

# %%
lat_eth = {}
for eth in eth_lat.keys():
    for lat in eth_lat[eth]:
        if lat not in lat_eth.keys():
            lat_eth[lat] = []
        lat_eth[lat].append(eth)

for key in lat_eth.keys():
    lat_eth[key] = list(set(lat_eth[key]))

lat_eth
# Out:
# {'.': ['።'],
#  ' ': ['፡'],
#  ',': ['፣'],
#  ';': ['፤'],
#  ':': ['፦', '፥'],
#  '?': ['፧'],
#  'he': ['ሐ', 'ኼ', 'ⷔ', 'ኅ', 'ⷕ', 'ኄ', 'ሔ', 'ህ', 'ሄ', 'ሕ', 'ሀ'],
#  'ha': ['ሓ', 'ኀ', 'ሐ', 'ሃ', 'ⷐ', 'ኻ', 'ኸ', 'ⷓ', 'ሀ', 'ኃ'],
#  'hu': ['ⷑ', 'ሑ', 'ኁ', 'ሁ', 'ኹ'],
#  'hi': ['ሒ', 'ሂ', 'ኅ', 'ኂ', 'ⷒ', 'ህ', 'ሕ', 'ኺ', 'ኽ'],
#  'h': ['ሕ', 'ህ'],
#  'hwo': ['ሆ', 'ኾ', 'ሖ', 'ኆ'],
#  'ho': ['ⷖ', 'ሖ', 'ኆ', 'ኾ', 'ሆ'],
#  'la': ['ላ', 'ለ'],
#  'le': ['ለ', 'ሌ', 'ል'],
#  'lu': ['ሉ'],
#  'li': ['ል', 'ሊ'],
#  'lye': ['ሌ'],
#  'l': ['ል'],
#  'lwo': ['ሎ'],
#  'lo': ['ሎ'],
#  'lwa': ['ሏ'],
#  'hwa': ['ኋ', 'ሗ', 'ዃ', 'ኈ'],
#  'ma': ['መ', 'ማ', 'ፙ'],
#  'me': ['መ', 'ም', 'ሜ'],
#  'mu': ['ሙ'],
#  'mi': ['ሚ', 'ም'],
#  'mye': ['ሜ'],
#  'm': ['ም'],
#  'mo': ['ሞ'],
#  'mwo': ['ሞ'],
#  'mwe': ['ᎂ', 'ᎃ', 'ᎀ'],
#  'mwa': ['ሟ', 'ᎀ'],
#  'mwi': ['ᎁ'],
#  'mw': ['ᎃ'],
#  'sa': ['ሸ', 'ሣ', 'ፀ', 'ሠ', 'ጸ', 'ፃ', 'ሰ', 'ሻ', 'ጻ', 'ሳ'],
#  "'se": ['ሤ', 'ፀ', 'ሠ', 'ፄ'],
#  'su': ['ሡ', 'ፁ', 'ጹ', 'ሹ', 'ሱ'],
#  "'su": ['ሡ', 'ፁ'],
#  'si': ['ጽ', 'ፂ', 'ስ', 'ሽ', 'ሲ', 'ፅ', 'ሥ', 'ጺ', 'ሢ', 'ሺ'],
#  "'si": ['ፂ', 'ሢ'],
#  "'sa": ['ሣ', 'ፃ'],
#  'se': ['ጸ', 'ጽ', 'ሼ', 'ስ', 'ሽ', 'ሤ', 'ሴ', 'ሥ', 'ሰ', 'ፄ', 'ጼ'],
#  'sye': ['ሤ', 'ጼ', 'ሴ', 'ፄ'],
#  "'s": ['ፅ', 'ሥ'],
#  "'so": ['ፆ', 'ሦ'],
#  'swo': ['ሾ', 'ሶ', 'ጾ', 'ሦ', 'ፆ'],
#  'so': ['ሾ', 'ሶ', 'ጾ', 'ሦ', 'ፆ'],
#  "'swa": ['ሧ'],
#  'swa': ['ሧ', 'ጿ', 'ሿ', 'ሷ'],
#  're': ['ር', 'ረ', 'ሬ'],
#  'ra': ['ራ', 'ረ'],
#  'ru': ['ሩ'],
#  'ri': ['ፘ', 'ሪ', 'ር'],
#  'rye': ['ሬ'],
#  'r': ['ር'],
#  'ro': ['ሮ'],
#  'rwo': ['ሮ'],
#  'rwa': ['ሯ'],
#  's': ['ስ', 'ጽ'],
#  'xe': ['ሸ', 'ኼ', 'ⷔ', 'ሼ', 'ⷐ'],
#  'sha': ['ሸ', 'ሻ'],
#  'cha': ['ሸ', 'ቸ', 'ሻ', 'ጨ', 'ቻ', 'ጫ'],
#  'xu': ['ሹ', 'ⷑ', 'ኹ'],
#  'chu': ['ሹ', 'ቹ', 'ጩ'],
#  'shu': ['ሹ'],
#  'shi': ['ሽ', 'ሺ'],
#  'xi': ['ⷒ', 'ኺ', 'ሺ'],
#  'chi': ['ች', 'ጭ', 'ጪ', 'ቺ', 'ሺ'],
#  'xa': ['ሻ', 'ኻ', 'ኸ', 'ⷓ'],
#  'she': ['ሼ'],
#  'che': ['ሼ', 'ሽ', 'ጬ', 'ቼ'],
#  'x': ['ሽ', 'ⷕ'],
#  'cho': ['ሾ', 'ጮ', 'ቾ'],
#  'xo': ['ⷖ', 'ሾ', 'ኾ'],
#  'sho': ['ሾ'],
#  'xwa': ['ሿ'],
#  'shwa': ['ሿ'],
#  'qa': ['ቀ', 'ቃ', 'ⷃ', 'ⷀ', 'ቓ', 'ቒ', 'ቐ'],
#  'qe': ['ቀ', 'ⷅ', 'ቔ', 'ⷄ', 'ቅ', 'ቕ', 'ቐ', 'ቄ'],
#  'ka': ['ቀ', 'ቃ', 'ከ', 'ⷋ', 'ካ', 'ኻ', 'ⷈ', 'ኸ'],
#  'qu': ['ⷁ', 'ቁ', 'ቑ'],
#  'ku': ['ⷉ', 'ኹ', 'ቁ', 'ኩ'],
#  'qi': ['ቒ', 'ⷂ', 'ቂ', 'ቑ'],
#  'ki': ['ቅ', 'ክ', 'ⷊ', 'ኪ', 'ቂ', 'ኺ'],
#  'qye': ['ቄ'],
#  'ke': ['ከ', 'ኼ', 'ክ', 'ⷍ', 'ⷌ', 'ቄ', 'ኸ', 'ኽ', 'ኬ'],
#  'q': ['ቕ', 'ቅ'],
#  'ko': ['ቆ', 'ⷎ', 'ኮ', 'ኾ'],
#  'qwo': ['ቆ'],
#  'qo': ['ቆ', 'ቖ', 'ቕ', 'ⷆ'],
#  'qwa': ['ቘ', 'ቋ', 'ቈ', 'ቛ'],
#  'kwa': ['ኳ', 'ቋ', 'ዀ', 'ዃ', 'ኰ', 'ቈ'],
#  'qwe': ['ቜ', 'ቍ', 'ቌ', 'ቘ', 'ቝ', 'ቈ'],
#  'qua': ['ቋ', 'ቈ'],
#  'kwe': ['ዄ', 'ኴ', 'ዅ', 'ቌ', 'ዀ', 'ኰ', 'ቈ', 'ኵ'],
#  'qui': ['ቊ'],
#  'kwi': ['ዂ', 'ቊ', 'ቍ', 'ኲ', 'ኵ'],
#  'qwi': ['ቊ', 'ቚ'],
#  'que': ['ቌ', 'ቍ'],
#  'qw': ['ቝ', 'ቍ'],
#  "'qe": ['ⷀ', 'ⷄ'],
#  "'qu": ['ⷁ'],
#  "'qi": ['ⷂ'],
#  "'qa": ['ⷃ'],
#  "'q": ['ⷅ'],
#  "'qo": ['ⷆ'],
#  'ba': ['ባ', 'በ'],
#  'be': ['ቤ', 'ብ', 'በ'],
#  'bu': ['ቡ'],
#  'bi': ['ቢ', 'ብ'],
#  'bye': ['ቤ'],
#  'b': ['ብ'],
#  'bwo': ['ቦ'],
#  'bo': ['ቦ'],
#  'bwe': ['ᎄ', 'ᎇ', 'ᎆ'],
#  'bwa': ['ᎄ', 'ቧ'],
#  'bwi': ['ᎅ'],
#  'bw': ['ᎇ'],
#  've': ['ቭ', 'ቬ', 'ቨ'],
#  'va': ['ቫ', 'ቨ'],
#  'vu': ['ቩ'],
#  'vi': ['ቪ', 'ቭ'],
#  'v': ['ቭ'],
#  'vo': ['ቮ'],
#  'vwa': ['ቯ'],
#  'ta': ['ጠ', 'ተ', 'ታ', 'ጣ'],
#  'te': ['ጥ', 'ተ', 'ቴ', 'ጤ', 'ጠ', 'ት'],
#  'tu': ['ጡ', 'ቱ'],
#  'ti': ['ጥ', 'ቲ', 'ት', 'ጢ'],
#  'tye': ['ቴ', 'ጤ'],
#  't': ['ጥ', 'ት'],
#  'two': ['ቶ', 'ጦ'],
#  'to': ['ቶ', 'ጦ'],
#  'twa': ['ቷ', 'ጧ'],
#  'ce': ['ች', 'ጭ', 'ጬ', 'ቸ', 'ቼ', 'ጨ', 'ፅ', 'ፄ'],
#  'ca': ['ፀ', 'ፃ', 'ቸ', 'ጨ', 'ቻ', 'ጫ'],
#  'tcha': ['ቸ', 'ቻ'],
#  'tchu': ['ቹ'],
#  'cu': ['ጩ', 'ፁ', 'ቹ'],
#  'ci': ['ች', 'ጭ', 'ፂ', 'ጪ', 'ቺ'],
#  'tchi': ['ቺ'],
#  'tche': ['ች', 'ቼ'],
#  'c': ['ች', 'ጭ'],
#  'cwo': ['ጮ', 'ቾ'],
#  'co': ['ፆ', 'ጮ', 'ቾ'],
#  'tcho': ['ቾ'],
#  'chwa': ['ቿ', 'ጯ'],
#  'cwa': ['ቿ', 'ጯ'],
#  "'he": ['ኄ', 'ኀ'],
#  "'hu": ['ኁ'],
#  "'hi": ['ኂ'],
#  "'ha": ['ኃ'],
#  "'h": ['ኅ'],
#  "'ho": ['ኆ'],
#  'hwe': ['ኌ', 'ኍ', 'ኈ'],
#  'hua': ['ኋ', 'ኈ'],
#  'hwi': ['ኍ', 'ኊ'],
#  'hui': ['ኊ'],
#  'hue': ['ኌ', 'ኍ'],
#  'hw': ['ኍ'],
#  'na': ['ና', 'ነ', 'ኛ', 'ኘ'],
#  'ne': ['ኔ', 'ኜ', 'ን', 'ነ', 'ኘ', 'ኝ'],
#  'nu': ['ኙ', 'ኑ'],
#  'ni': ['ኝ', 'ኒ', 'ን', 'ኚ'],
#  "na'": ['ና'],
#  'nye': ['ኔ'],
#  'n': ['ኝ', 'ን'],
#  'nwo': ['ኖ', 'ኞ'],
#  'no': ['ኖ', 'ኞ'],
#  'nwa': ['ኗ', 'ኟ'],
#  'gna': ['ኛ', 'ኘ'],
#  'gnu': ['ኙ'],
#  'gni': ['ኚ'],
#  'gne': ['ኝ', 'ኜ'],
#  'gno': ['ኞ'],
#  '`a': ['ዓ', 'ዐ', 'ኣ', 'አ'],
#  "'a": ['ዓ', 'ዐ', 'ኣ', 'አ'],
#  'a': ['ዐ', 'ኧ', 'አ', 'ዓ', 'ኣ'],
#  '`u': ['ዑ', 'ኡ'],
#  "'u": ['ዑ', 'ኡ'],
#  'u': ['ዑ', 'ኡ'],
#  "'i": ['ዕ', 'ኢ', 'ዒ'],
#  'i': ['ዕ', 'ኢ', 'እ', 'ዒ'],
#  '`i': ['ኢ', 'ዒ'],
#  'e': ['ዔ', 'ኤ'],
#  'ye': ['የ', 'ኤ', 'ይ', 'ዬ', 'ዔ'],
#  "'e": ['ዐ', 'እ', 'ኤ', 'ዕ', 'ዔ'],
#  '`e': ['ዕ', 'እ', 'ዔ', 'ኤ'],
#  "'o": ['ዖ', 'ኦ'],
#  'o': ['ዖ', 'ኦ'],
#  'wo': ['ዖ', 'ኦ', 'ዎ'],
#  '`o': ['ዖ', 'ኦ'],
#  "'wa": ['ኧ'],
#  'a-': ['ኧ'],
#  'ea': ['ኧ'],
#  'kye': ['ኬ'],
#  'k': ['ክ', 'ኽ'],
#  'kwo': ['ኮ'],
#  'kua': ['ኳ', 'ኰ'],
#  'kui': ['ኲ'],
#  'kue': ['ኴ', 'ኵ'],
#  'kw': ['ዅ', 'ኵ'],
#  "'ke": ['ⷌ', 'ⷈ'],
#  "'ku": ['ⷉ'],
#  "'ki": ['ⷊ'],
#  "'ka": ['ⷋ'],
#  "'k": ['ⷍ'],
#  "'ko": ['ⷎ'],
#  'kha': ['ኻ', 'ኸ'],
#  'khu': ['ኹ'],
#  'khi': ['ኺ'],
#  'khe': ['ኼ', 'ኽ'],
#  'hye': ['ኼ'],
#  'kho': ['ኾ'],
#  'wa': ['ዋ', 'ወ'],
#  'we': ['ዌ', 'ው', 'ወ'],
#  'wu': ['ዉ'],
#  'wi': ['ዊ', 'ው'],
#  'wye': ['ዌ'],
#  'w': ['ው'],
#  'za': ['ዘ', 'ዛ', 'ዠ', 'ዣ'],
#  'ze': ['ዝ', 'ዠ', 'ዘ', 'ዥ', 'ዤ', 'ዜ'],
#  'zu': ['ዡ', 'ዙ'],
#  'zi': ['ዝ', 'ዢ', 'ዥ', 'ዚ'],
#  'zye': ['ዜ'],
#  'z': ['ዝ', 'ዥ'],
#  'zo': ['ዦ', 'ዞ'],
#  'zwo': ['ዦ', 'ዞ'],
#  'zwa': ['ዧ', 'ዟ'],
#  'ja': ['ጃ', 'ዠ', 'የ', 'ዣ', 'ጀ', 'ያ'],
#  'zha': ['ዠ', 'ዣ'],
#  'ju': ['ጁ', 'ዡ', 'ዩ'],
#  'zhu': ['ዡ'],
#  'ji': ['ዢ', 'ጅ', 'ዪ', 'ጂ'],
#  'zhi': ['ዥ', 'ዢ'],
#  'je': ['ጄ', 'ዥ', 'ዤ', 'ጀ', 'ይ', 'ዬ'],
#  'zhe': ['ዤ'],
#  'jo': ['ዦ', 'ጆ', 'ዮ'],
#  'zho': ['ዦ'],
#  'zhwa': ['ዧ'],
#  'ya': ['ያ', 'የ'],
#  'yu': ['ዩ'],
#  'yi': ['ዪ', 'ይ'],
#  'y': ['ይ'],
#  'yo': ['ዮ'],
#  'da': ['ፀ', 'ፃ', 'ደ', 'ዻ', 'ዸ', 'ዳ'],
#  'de': ['ዽ', 'ደ', 'ፅ', 'ፄ', 'ዸ', 'ዴ', 'ዼ', 'ድ'],
#  'du': ['ዹ', 'ፁ', 'ዱ'],
#  'di': ['ዲ', 'ፂ', 'ዺ', 'ድ'],
#  'dye': ['ዴ'],
#  'd': ['ዽ', 'ድ'],
#  'dwo': ['ዶ'],
#  'do': ['ፆ', 'ዾ', 'ዶ'],
#  'dwa': ['ዿ', 'ዷ'],
#  'dja': ['ጃ', 'ጀ'],
#  'ga': ['ⷛ', 'ጃ', 'ጋ', 'ጛ', 'ጀ', 'ጘ', 'ገ', 'ⷘ'],
#  'gu': ['ጁ', 'ⷙ', 'ጉ', 'ጙ'],
#  'dju': ['ጁ'],
#  'dji': ['ጂ'],
#  'gi': ['ጚ', 'ግ', 'ጂ', 'ጊ', 'ⷚ'],
#  'dje': ['ጅ', 'ጄ'],
#  'ge': ['ጌ', 'ⷝ', 'ግ', 'ጄ', 'ጜ', 'ጘ', 'ገ', 'ⷜ', 'ጅ', 'ጝ'],
#  'j': ['ጅ'],
#  'gwo': ['ጎ', 'ጆ'],
#  'go': ['ጎ', 'ጆ', 'ጞ', 'ⷞ'],
#  'djo': ['ጆ'],
#  'gwa': ['ጐ', 'ጓ', 'ⶓ', 'ጟ', 'ጇ'],
#  'jwa': ['ጇ'],
#  'gye': ['ጌ'],
#  'g': ['ግ', 'ጝ'],
#  'gua': ['ጐ', 'ጓ'],
#  'gwe': ['ጐ', 'ⶖ', 'ጔ', 'ጕ', 'ⶓ', 'ⶕ'],
#  'gui': ['ጒ'],
#  'gwi': ['ⶔ', 'ጕ', 'ጒ'],
#  'gue': ['ጔ', 'ጕ'],
#  'gw': ['ⶖ', 'ጕ'],
#  "'ge": ['ⷜ', 'ⷘ'],
#  "'gu": ['ⷙ'],
#  "'gi": ['ⷚ'],
#  "'ga": ['ⷛ'],
#  "'g": ['ⷝ'],
#  "'go": ['ⷞ'],
#  "tch'a": ['ጨ', 'ጫ'],
#  "tch'u": ['ጩ'],
#  "tch'i": ['ጪ'],
#  "tch'e": ['ጭ', 'ጬ'],
#  "tch'o": ['ጮ'],
#  'pe': ['ጰ', 'ፔ', 'ፐ', 'ፕ', 'ጵ', 'ጴ'],
#  'pa': ['ጳ', 'ፐ', 'ፓ', 'ጰ'],
#  'pu': ['ጱ', 'ፑ'],
#  'pi': ['ጵ', 'ፒ', 'ጲ', 'ፕ'],
#  'pye': ['ፔ', 'ጴ'],
#  'p': ['ጵ', 'ፕ'],
#  'po': ['ፖ', 'ጶ'],
#  'pwo': ['ፖ', 'ጶ'],
#  'pwa': ['ᎌ', 'ጷ', 'ፗ'],
#  'tsa': ['ጻ', 'ፀ', 'ጸ', 'ፃ'],
#  'tsu': ['ፁ', 'ጹ'],
#  'tsi': ['ፂ', 'ጺ'],
#  'tse': ['ጼ', 'ፄ'],
#  'tso': ['ፆ', 'ጾ'],
#  'fe': ['ፍ', 'ፌ', 'ፈ'],
#  'fa': ['ፋ', 'ፈ'],
#  'fu': ['ፉ'],
#  'fi': ['ፚ', 'ፊ', 'ፍ'],
#  'fye': ['ፌ'],
#  'f': ['ፍ'],
#  'fo': ['ፎ'],
#  'fwo': ['ፎ'],
#  'fwa': ['ፏ', 'ᎈ'],
#  'fwe': ['ᎋ', 'ᎈ', 'ᎊ'],
#  'fwi': ['ᎉ'],
#  'fw': ['ᎋ'],
#  'pwe': ['ᎎ', 'ᎌ', 'ᎏ'],
#  'pwi': ['ᎍ'],
#  'pw': ['ᎏ'],
#  'rya': ['ፘ'],
#  'mya': ['ፙ'],
#  'fya': ['ፚ']}

# %%
with open("lat_eth.json", 'w') as f:
    json.dump(lat_eth, f)
