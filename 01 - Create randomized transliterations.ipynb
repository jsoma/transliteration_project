# %% [markdown]
# # Import lookup table

# %%
import random
import json
import string
import unidecode
import regex

# %%
with open("raw/lookup-table.json") as f:
    lookup = json.load(f)

lookup
# Out:
# {'።': '.',
#  '፡': ' ',
#  '፣': ',',
#  '፤': ';',
#  '፥': ':',
#  '፧': '?',
#  '፦': ':',
#  'ሀ': ['he', 'ha'],
#  'ሁ': ['hu'],
#  'ሂ': ['hi'],
#  'ሃ': ['ha'],
#  'ሄ': ['he'],
#  'ህ': ['he', 'hi', 'h'],
#  'ሆ': ['hwo', 'ho'],
#  'ለ': ['la', 'le'],
#  'ሉ': ['lu'],
#  'ሊ': ['li'],
#  'ላ': ['la'],
#  'ሌ': ['lye', 'le'],
#  'ል': ['l', 'li', 'le'],
#  'ሎ': ['lo', 'lwo'],
#  'ሏ': ['lwa'],
#  'ሐ': ['he', 'ha'],
#  'ሑ': ['hu'],
#  'ሒ': ['hi'],
#  'ሓ': ['ha'],
#  'ሔ': ['he'],
#  'ሕ': ['he', 'hi', 'h'],
#  'ሖ': ['hwo', 'ho'],
#  'ሗ': ['hwa'],
#  'መ': ['ma', 'me'],
#  'ሙ': ['mu'],
#  'ሚ': ['mi'],
#  'ማ': ['ma'],
#  'ሜ': ['mye', 'me'],
#  'ም': ['m', 'mi', 'me'],
#  'ሞ': ['mwo', 'mo'],
#  'ᎀ': ['mwa', 'mwe'],
#  'ᎁ': ['mwi'],
#  'ሟ': ['mwa'],
#  'ᎂ': ['mwe'],
#  'ᎃ': ['mw', 'mwe'],
#  'ሠ': ['sa', "'se"],
#  'ሡ': ['su', "'su"],
#  'ሢ': ["'si", 'si'],
#  'ሣ': ["'sa", 'sa'],
#  'ሤ': ['se', 'sye', "'se"],
#  'ሥ': ["'s", 'se', 'si'],
#  'ሦ': ["'so", 'swo', 'so'],
#  'ሧ': ["'swa", 'swa'],
#  'ረ': ['ra', 're'],
#  'ሩ': ['ru'],
#  'ሪ': ['ri'],
#  'ራ': ['ra'],
#  'ሬ': ['re', 'rye'],
#  'ር': ['re', 'ri', 'r'],
#  'ሮ': ['rwo', 'ro'],
#  'ሯ': ['rwa'],
#  'ሰ': ['se', 'sa'],
#  'ሱ': ['su'],
#  'ሲ': ['si'],
#  'ሳ': ['sa'],
#  'ሴ': ['se', 'sye'],
#  'ስ': ['s', 'se', 'si'],
#  'ሶ': ['swo', 'so'],
#  'ሷ': ['swa'],
#  'ሸ': ['cha', 'xe', 'sha', 'sa'],
#  'ሹ': ['chu', 'su', 'xu', 'shu'],
#  'ሺ': ['xi', 'shi', 'chi', 'si'],
#  'ሻ': ['cha', 'sha', 'xa', 'sa'],
#  'ሼ': ['she', 'se', 'che', 'xe'],
#  'ሽ': ['shi', 'se', 'che', 'x', 'si'],
#  'ሾ': ['sho', 'cho', 'swo', 'so', 'xo'],
#  'ሿ': ['xwa', 'shwa', 'swa'],
#  'ቀ': ['ka', 'qa', 'qe'],
#  'ቁ': ['qu', 'ku'],
#  'ቂ': ['ki', 'qi'],
#  'ቃ': ['ka', 'qa'],
#  'ቄ': ['qye', 'ke', 'qe'],
#  'ቅ': ['ki', 'q', 'qe'],
#  'ቆ': ['qwo', 'ko', 'qo'],
#  'ቇ': [],
#  'ቈ': ['kwa', 'kwe', 'qwa', 'qwe', 'qua'],
#  'ቊ': ['qwi', 'qui', 'kwi'],
#  'ቋ': ['kwa', 'qwa', 'qua'],
#  'ቌ': ['que', 'kwe', 'qwe'],
#  'ቍ': ['qw', 'kwi', 'que', 'qwe'],
#  'ⷀ': ["'qe", 'qa'],
#  'ⷁ': ['qu', "'qu"],
#  'ⷂ': ['qi', "'qi"],
#  'ⷃ': ["'qa", 'qa'],
#  'ⷄ': ["'qe", 'qe'],
#  'ⷅ': ["'q", 'qe'],
#  'ⷆ': ['qo', "'qo"],
#  'ቐ': ['qa', 'qe'],
#  'ቑ': ['qu', 'qi'],
#  'ቒ': ['qi', 'qa'],
#  'ቓ': ['qa'],
#  'ቔ': ['qe'],
#  'ቕ': ['q', 'qo', 'qe'],
#  'ቖ': ['qo'],
#  'ቘ': ['qwe', 'qwa'],
#  'ቚ': ['qwi'],
#  'ቛ': ['qwa'],
#  'ቜ': ['qwe'],
#  'ቝ': ['qw', 'qwe'],
#  'በ': ['be', 'ba'],
#  'ቡ': ['bu'],
#  'ቢ': ['bi'],
#  'ባ': ['ba'],
#  'ቤ': ['bye', 'be'],
#  'ብ': ['bi', 'be', 'b'],
#  'ቦ': ['bo', 'bwo'],
#  'ᎄ': ['bwa', 'bwe'],
#  'ᎅ': ['bwi'],
#  'ቧ': ['bwa'],
#  'ᎆ': ['bwe'],
#  'ᎇ': ['bw', 'bwe'],
#  'ቨ': ['va', 've'],
#  'ቩ': ['vu'],
#  'ቪ': ['vi'],
#  'ቫ': ['va'],
#  'ቬ': ['ve'],
#  'ቭ': ['vi', 've', 'v'],
#  'ቮ': ['vo'],
#  'ቯ': ['vwa'],
#  'ተ': ['ta', 'te'],
#  'ቱ': ['tu'],
#  'ቲ': ['ti'],
#  'ታ': ['ta'],
#  'ቴ': ['tye', 'te'],
#  'ት': ['t', 'te', 'ti'],
#  'ቶ': ['to', 'two'],
#  'ቷ': ['twa'],
#  'ቸ': ['cha', 'ca', 'tcha', 'ce'],
#  'ቹ': ['cu', 'chu', 'tchu'],
#  'ቺ': ['chi', 'tchi', 'ci'],
#  'ቻ': ['cha', 'ca', 'tcha'],
#  'ቼ': ['ce', 'tche', 'che'],
#  'ች': ['tche', 'chi', 'c', 'ce', 'ci'],
#  'ቾ': ['co', 'tcho', 'cwo', 'cho'],
#  'ቿ': ['cwa', 'chwa'],
#  'ኀ': ['ha', "'he"],
#  'ኁ': ['hu', "'hu"],
#  'ኂ': ["'hi", 'hi'],
#  'ኃ': ['ha', "'ha"],
#  'ኄ': ['he', "'he"],
#  'ኅ': ['he', 'hi', "'h"],
#  'ኆ': ["'ho", 'hwo', 'ho'],
#  'ኈ': ['hwa', 'hwe', 'hua'],
#  'ኊ': ['hui', 'hwi'],
#  'ኋ': ['hwa', 'hua'],
#  'ኌ': ['hue', 'hwe'],
#  'ኍ': ['hue', 'hwe', 'hwi', 'hw'],
#  'ነ': ['ne', 'na'],
#  'ኑ': ['nu'],
#  'ኒ': ['ni'],
#  'ና': ["na'", 'na'],
#  'ኔ': ['nye', 'ne'],
#  'ን': ['ni', 'ne', 'n'],
#  'ኖ': ['no', 'nwo'],
#  'ኗ': ['nwa'],
#  'ኘ': ['gna', 'ne', 'na'],
#  'ኙ': ['gnu', 'nu'],
#  'ኚ': ['gni', 'ni'],
#  'ኛ': ['gna', 'na'],
#  'ኜ': ['gne', 'ne'],
#  'ኝ': ['n', 'gne', 'ni', 'ne'],
#  'ኞ': ['no', 'nwo', 'gno'],
#  'ኟ': ['nwa'],
#  'አ': ['`a', "'a", 'a'],
#  'ኡ': ['`u', 'u', "'u"],
#  'ኢ': ['i', '`i', "'i"],
#  'ኣ': ['`a', "'a", 'a'],
#  'ኤ': ["'e", 'e', 'ye', '`e'],
#  'እ': ["'e", 'i', '`e'],
#  'ኦ': ['o', '`o', 'wo', "'o"],
#  'ኧ': ['a-', "'wa", 'ea', 'a'],
#  'ከ': ['ka', 'ke'],
#  'ኩ': ['ku'],
#  'ኪ': ['ki'],
#  'ካ': ['ka'],
#  'ኬ': ['ke', 'kye'],
#  'ክ': ['ki', 'ke', 'k'],
#  'ኮ': ['ko', 'kwo'],
#  'ኯ': [],
#  'ኰ': ['kwa', 'kua', 'kwe'],
#  'ኲ': ['kui', 'kwi'],
#  'ኳ': ['kwa', 'kua'],
#  'ኴ': ['kwe', 'kue'],
#  'ኵ': ['kwe', 'kw', 'kwi', 'kue'],
#  'ⷈ': ['ka', "'ke"],
#  'ⷉ': ["'ku", 'ku'],
#  'ⷊ': ['ki', "'ki"],
#  'ⷋ': ['ka', "'ka"],
#  'ⷌ': ['ke', "'ke"],
#  'ⷍ': ['ke', "'k"],
#  'ⷎ': ['ko', "'ko"],
#  'ኸ': ['ka', 'kha', 'ha', 'ke', 'xa'],
#  'ኹ': ['hu', 'khu', 'xu', 'ku'],
#  'ኺ': ['ki', 'xi', 'hi', 'khi'],
#  'ኻ': ['ha', 'ka', 'xa', 'kha'],
#  'ኼ': ['he', 'hye', 'xe', 'khe', 'ke'],
#  'ኽ': ['khe', 'k', 'ke', 'hi'],
#  'ኾ': ['ho', 'kho', 'ko', 'xo', 'hwo'],
#  'ዀ': ['kwa', 'kwe'],
#  'ዂ': ['kwi'],
#  'ዃ': ['kwa', 'hwa'],
#  'ዄ': ['kwe'],
#  'ዅ': ['kwe', 'kw'],
#  'ⷐ': ['ha', 'xe'],
#  'ⷑ': ['hu', 'xu'],
#  'ⷒ': ['xi', 'hi'],
#  'ⷓ': ['ha', 'xa'],
#  'ⷔ': ['he', 'xe'],
#  'ⷕ': ['he', 'x'],
#  'ⷖ': ['xo', 'ho'],
#  'ወ': ['we', 'wa'],
#  'ዉ': ['wu'],
#  'ዊ': ['wi'],
#  'ዋ': ['wa'],
#  'ዌ': ['wye', 'we'],
#  'ው': ['wi', 'we', 'w'],
#  'ዎ': ['wo'],
#  'ዐ': ["'e", '`a', "'a", 'a'],
#  'ዑ': ['`u', 'u', "'u"],
#  'ዒ': ['i', '`i', "'i"],
#  'ዓ': ['`a', "'a", 'a'],
#  'ዔ': ["'e", 'e', 'ye', '`e'],
#  'ዕ': ["'e", "'i", '`e', 'i'],
#  'ዖ': ['o', "'o", 'wo', '`o'],
#  'ዘ': ['ze', 'za'],
#  'ዙ': ['zu'],
#  'ዚ': ['zi'],
#  'ዛ': ['za'],
#  'ዜ': ['zye', 'ze'],
#  'ዝ': ['z', 'ze', 'zi'],
#  'ዞ': ['zwo', 'zo'],
#  'ዟ': ['zwa'],
#  'ዠ': ['ze', 'za', 'zha', 'ja'],
#  'ዡ': ['zu', 'ju', 'zhu'],
#  'ዢ': ['ji', 'zhi', 'zi'],
#  'ዣ': ['ja', 'za', 'zha'],
#  'ዤ': ['zhe', 'ze', 'je'],
#  'ዥ': ['ze', 'zi', 'z', 'zhi', 'je'],
#  'ዦ': ['zwo', 'zo', 'zho', 'jo'],
#  'ዧ': ['zwa', 'zhwa'],
#  'የ': ['ya', 'ye', 'ja'],
#  'ዩ': ['ju', 'yu'],
#  'ዪ': ['ji', 'yi'],
#  'ያ': ['ya', 'ja'],
#  'ዬ': ['ye', 'je'],
#  'ይ': ['ye', 'y', 'yi', 'je'],
#  'ዮ': ['yo', 'jo'],
#  'ደ': ['da', 'de'],
#  'ዱ': ['du'],
#  'ዲ': ['di'],
#  'ዳ': ['da'],
#  'ዴ': ['dye', 'de'],
#  'ድ': ['d', 'de', 'di'],
#  'ዶ': ['do', 'dwo'],
#  'ዷ': ['dwa'],
#  'ዸ': ['da', 'de'],
#  'ዹ': ['du'],
#  'ዺ': ['di'],
#  'ዻ': ['da'],
#  'ዼ': ['de'],
#  'ዽ': ['d', 'de'],
#  'ዾ': ['do'],
#  'ዿ': ['dwa'],
#  'ጀ': ['ga', 'je', 'ja', 'dja'],
#  'ጁ': ['ju', 'dju', 'gu'],
#  'ጂ': ['gi', 'ji', 'dji'],
#  'ጃ': ['ja', 'ga', 'dja'],
#  'ጄ': ['dje', 'ge', 'je'],
#  'ጅ': ['ji', 'dje', 'ge', 'j'],
#  'ጆ': ['go', 'djo', 'jo', 'gwo'],
#  'ጇ': ['jwa', 'gwa'],
#  'ገ': ['ge', 'ga'],
#  'ጉ': ['gu'],
#  'ጊ': ['gi'],
#  'ጋ': ['ga'],
#  'ጌ': ['ge', 'gye'],
#  'ግ': ['gi', 'ge', 'g'],
#  'ጎ': ['go', 'gwo'],
#  'ጐ': ['gua', 'gwe', 'gwa'],
#  'ጒ': ['gwi', 'gui'],
#  'ጓ': ['gua', 'gwa'],
#  'ጔ': ['gwe', 'gue'],
#  'ጕ': ['gwi', 'gue', 'gw', 'gwe'],
#  'ⷘ': ['ga', "'ge"],
#  'ⷙ': ['gu', "'gu"],
#  'ⷚ': ['gi', "'gi"],
#  'ⷛ': ["'ga", 'ga'],
#  'ⷜ': ['ge', "'ge"],
#  'ⷝ': ["'g", 'ge'],
#  'ⷞ': ['go', "'go"],
#  'ጘ': ['ge', 'ga'],
#  'ጙ': ['gu'],
#  'ጚ': ['gi'],
#  'ጛ': ['ga'],
#  'ጜ': ['ge'],
#  'ጝ': ['ge', 'g'],
#  'ጞ': ['go'],
#  'ⶓ': ['gwe', 'gwa'],
#  'ⶔ': ['gwi'],
#  'ጟ': ['gwa'],
#  'ⶕ': ['gwe'],
#  'ⶖ': ['gwe', 'gw'],
#  'ጠ': ['ta', 'te'],
#  'ጡ': ['tu'],
#  'ጢ': ['ti'],
#  'ጣ': ['ta'],
#  'ጤ': ['tye', 'te'],
#  'ጥ': ['t', 'te', 'ti'],
#  'ጦ': ['to', 'two'],
#  'ጧ': ['twa'],
#  'ጨ': ['cha', "tch'a", 'ca', 'ce'],
#  'ጩ': ["tch'u", 'cu', 'chu'],
#  'ጪ': ["tch'i", 'chi', 'ci'],
#  'ጫ': ["tch'a", 'cha', 'ca'],
#  'ጬ': ['ce', "tch'e", 'che'],
#  'ጭ': ["tch'e", 'chi', 'c', 'ce', 'ci'],
#  'ጮ': ['co', 'cwo', "tch'o", 'cho'],
#  'ጯ': ['cwa', 'chwa'],
#  'ጰ': ['pa', 'pe'],
#  'ጱ': ['pu'],
#  'ጲ': ['pi'],
#  'ጳ': ['pa'],
#  'ጴ': ['pe', 'pye'],
#  'ጵ': ['pi', 'pe', 'p'],
#  'ጶ': ['pwo', 'po'],
#  'ጷ': ['pwa'],
#  'ጸ': ['tsa', 'se', 'sa'],
#  'ጹ': ['su', 'tsu'],
#  'ጺ': ['tsi', 'si'],
#  'ጻ': ['tsa', 'sa'],
#  'ጼ': ['tse', 'se', 'sye'],
#  'ጽ': ['s', 'se', 'si'],
#  'ጾ': ['tso', 'swo', 'so'],
#  'ጿ': ['swa'],
#  'ፀ': ['tsa', 'sa', 'ca', 'da', "'se"],
#  'ፁ': ['tsu', "'su", 'du', 'cu', 'su'],
#  'ፂ': ["'si", 'di', 'si', 'tsi', 'ci'],
#  'ፃ': ["'sa", 'tsa', 'sa', 'ca', 'da'],
#  'ፄ': ['se', 'sye', 'tse', 'de', 'ce', "'se"],
#  'ፅ': ['ce', "'s", 'de', 'si'],
#  'ፆ': ["'so", 'swo', 'so', 'co', 'tso', 'do'],
#  'ፈ': ['fa', 'fe'],
#  'ፉ': ['fu'],
#  'ፊ': ['fi'],
#  'ፋ': ['fa'],
#  'ፌ': ['fye', 'fe'],
#  'ፍ': ['fi', 'f', 'fe'],
#  'ፎ': ['fo', 'fwo'],
#  'ᎈ': ['fwa', 'fwe'],
#  'ᎉ': ['fwi'],
#  'ፏ': ['fwa'],
#  'ᎊ': ['fwe'],
#  'ᎋ': ['fw', 'fwe'],
#  'ፐ': ['pa', 'pe'],
#  'ፑ': ['pu'],
#  'ፒ': ['pi'],
#  'ፓ': ['pa'],
#  'ፔ': ['pe', 'pye'],
#  'ፕ': ['pi', 'pe', 'p'],
#  'ፖ': ['pwo', 'po'],
#  'ᎌ': ['pwe', 'pwa'],
#  'ᎍ': ['pwi'],
#  'ፗ': ['pwa'],
#  'ᎎ': ['pwe'],
#  'ᎏ': ['pwe', 'pw'],
#  'ፘ': ['ri', 'rya'],
#  'ፙ': ['ma', 'mya'],
#  'ፚ': ['fya', 'fi']}

# %% [markdown]
# # Tools to build randomized transliterations

# %%
import re

failures = set([])

def select_char(c):
    # If it's not in the lookup table, that's ok
    try:
        return random.choice(lookup[c])
    except:
        failures.add(c)
        return unidecode.unidecode(c).lower()

def transliterate(word):
    selected = ''.join([select_char(c) for c in word])
    selected = selected.replace("፡", " ")
    selected = re.sub(r'\s+', ' ', selected)
    return selected.strip()

# %%
text = "ማንም፡ሰው፡ቢሆን፡የጭካኔ፡ስቃይ፡እንዳይደርስበት፡ወይም፡ከሰብዓዊ፡አፈጻጸም፡ውጭ፡የሆነ፡የተዋረድ፡ተግባር፡ወይም፡ቅጣት፡አይፈጸምበትም።"

transliterate(text)
# Out:
# "manimi sewe bihone yecekanye skayi indayedarisibete weyim kasabeawi `afetsasem wtch'e yahone yetawaredi tegbare weyemi kitate 'ayfasemebatm."

# %%
for _ in range(5):
    result = transliterate(text)
    print(f"* {result}")
# Out:
# * manm sawi bihwone yacekane sqay `enedaydarisebate weyeme kaseb'awi `afatsasam weci yehona yatawared tegebari wayemi qtat `ajefasamebatme.
# * manem sew bihon yetch'ekanye seqayi 'enedaydarsbati wejem kasabawi 'afatsasami wici yahwona yetawarade tagibare wayim qtati ayefatsambatme.
# * manimi sawi bihon jacekanye skayi `enedajederesebate weym kesebe`awi 'afesaseme wce jahona yetewaradi tegibare weyime qtati 'ajefesemebatme.
# * maneme sewe bihwon jachikanye siqayi indayedarisbeti wayim kasab'awi afasatsam wce jahone yetawarad tegbare weyemi qetate `ayfesemebatme.
# * manime sew bihone jacekane sqaje inedayiderisibete weyime kasebe'awi `afasatsame wec jahwone yatewarede tegbar wayem qtati ayfasamibetimi.

# %% [markdown]
# # Use it
#
# Using data from `new-am.txt`, which is Bible + legal + news.

# %%
#text = open("corpuscrawler-master/corpus/am.txt").readlines()
text = open("raw/new-am.txt").read().strip().splitlines()
text[:5]
# Out:
# ['ጠ/ሚ መለስ ዜናዊ "ጦርነት ኳስ ጨዋታ አይደለም!" አሉ',
#  'ሰሞኑን በሕወሓት/ኢሕአዴግ ግምገማ ውስጥ ዋነኛው የግምገማ በትር ያረፈው በጠ/ሚ መለስ ዜናዊ ላይ መሆኑ ተደጋግሞ እየተሰማ ነው።',
#  'ከዚሁ ጋር ተያይዞ የጠ/ሚንስትሩ ጋርዶች በሌሎች መቀየራቸው፣  ከአቶ መለስ ዜናዊ ጋር የሚያገናኙ የቤተ መንግሥት የስልክ ግንኙነቶች መቋረጣቸው በሰፊው እየተነገረ ሲሆን፣ማንኛውንም የወቅቱን ጉዳይ አስመልክቶ መነጋገር የሚቻለው ከውጭ ጉዳይ ሚ/ር መ/ቤት ጋር መሆኑ ታውቋል።',
#  'አቶ መለስ ዜናዊ በዚህ ሁኔታ ውስጥ መሆናቸው እየተነገረ ባለበት ወቅት ነው ከአሜሪካ ሬዲዮ ጋር ቃለ ምልልስ ያደረጉት።',
#  'በቃለ ምልልሱም ወቅት በሕወሓት አመራር አካል የኤርትራን ጥያቄ ልዩነት ነበር ይባላል።']

# %%
# Drop duplicates
uniques = [line for line in list(set(text)) if line]
len(uniques)
# Out:
# 48651

# %% [markdown]
# # Transliterate and save

# %%
import pandas as pd

def clean(text):
    # Remove invalid unicode chars
    # note it's the regex library, not re
    cleaned = regex.sub(r'(\p{Cn}|\p{Co}|\p{Cf}|\p{Cc})', '', text)
    
    # Replace space char with spaces
    cleaned = text.replace("፡", " ").strip()

    # Remove duplicate spaces
    cleaned = re.sub(r'\s+', ' ', cleaned)
    return cleaned

# Do you want to transliterate each row in multiple ways?
NUM_TRANSLITERATIONS = 2

sources = []
transliterateds = []
skipped = 0
for text in uniques:
    cleaned = clean(text)
    options = [transliterate(cleaned) for _ in range(NUM_TRANSLITERATIONS)]
    for transliteration in options:
        # Make sure we can split afterwards, some of these texts are real weird
        if len(cleaned.split(" ")) != len(transliteration.split(" ")):
            skipped = skipped + 1
        else:
            sources.append(cleaned)
            transliterateds.append(transliteration)

print("Skipped", skipped)
print("Fail chars:", failures)
# Out:
# Skipped 22
# Fail chars: {'፶', '5', ':', '(', '\uf033', '፮', '\ufeff', 'f', 'E', 'י', '8', 'p', 'h', '፳', '&', '3', 'D', 'd', 'ז', '\x81', '—', 'M', '6', '9', '፹', ',', '\uf032', 'Í', 'ש', 'e', 'V', '“', 'r', '*', 'צ', 'ת', '′', '`', '̧', 'z', 'x', '/', 'c', '\x9d', '፰', '$', '¾', 's', '»', 'm', '”', '‘', 'g', '^', 'B', 'Z', '́', 'ê', 'P', 'ד', '÷', 'ª', 'y', 'Q', '፬', 'K', '-', 'I', '፵', '\uf038', '’', '፭', '!', 'נ', 'ע', 'Y', '¬', 'R', 'G', '፲', '4', ' ', '@', '×', '፪', '̃', '፯', '\uf036', 'L', '፴', '#', ';', 'Ø', 'Ñ', 'n', '"', 'א', '1', '¨', '፸', '፩', 'S', '\uf037', 'u', 'q', 'v', 'l', '\xa0', ')', 'ƒ', 'U', 'w', '፱', '%', '¡', 'Ó', 'ב', '[', '2', "'", 'A', '̈', 'T', 'j', '\uf020', '©', '+', '<', '7', 'i', '=', '\uf035', '፷', 'F', '‹', '?', '.', '\uf031', '>', '\uf034', 'o', '\u2060', '፻', 'b', '0', '፺', 'W', 'ק', '￼', 'Á', 'k', 'ל', '›', 'Ï', 'a', 'ו', 'C', '«', '…', 'X', 't', 'Ÿ', 'ח', 'N', 'H', 'O', '፫', '}', '_', '\uf039', 'ነ', 'J', ']'}

# %%
# Shuffle so it's randomized
df = pd.DataFrame({
    'source': sources,
    'transliterated': transliterateds
}).sample(frac=1).reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (97280, 2)
#                                               source  \
# 0  ቀዝቃዛ ውኃ የዛለችን ነፍስ እንደሚያረካ ሁሉከሩቅ አገር የመጣ መልካም ወ...
# 1  በመልካም ሁኔታ የሚያስተዳድሩ በተለይ ደግሞ በመናገርና በማስተማር ተግተው...
# 2  መጽሐፍ ቅዱስ በመጨረሻዎቹ ቀናት ክፋት በከፍተኛ ሁኔታ እንደሚባባስ ይነግ...
# 3                       የአክሱም ሐውልት ሁለተኛው ክፋይ አክሱም ገባ
# 4      የሴም ወንዶች ልጆች ኤላም፣ አሹር፣ አርፋክስድ፣ ሉድ እና አራም ነበሩ።
#
#                                       transliterated
# 0  kazeqaza weha yazalatchene nefsi inidamiyaraka...
# 1  bemalkam huneta jamiyasitadaderu batelaye dagi...
# 2  mashefe qduse bemeceraxawotchu qana'te kefat b...
# 3      ye'akesum hawlte huletanaw kfaye akisume geba
# 4  yasyeme wanidwoce lgoce 'elam, `ashure, `arifa...

# %%
with open('raw/original.txt', 'w') as f:
    f.write('\n'.join(df.source))
    
with open('raw/transliterated.txt', 'w') as f:
    f.write('\n'.join(df.transliterated))

# %%
# !head -n 2 raw/original.txt

# %%
# !head -n 2 raw/transliterated.txt
